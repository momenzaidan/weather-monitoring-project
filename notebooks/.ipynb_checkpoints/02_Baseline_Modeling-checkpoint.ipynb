# %%
import pandas as pd
import numpy as np
import os
import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# --- ROBUST FILE LOADING ---
# We try three different possible paths to find your data
possible_paths = [
    os.path.join('..', 'data', 'raw_weather_data.csv'), # 1. If notebook is in /notebooks folder
    os.path.join('data', 'raw_weather_data.csv'),      # 2. If notebook is in the main project folder
    'raw_weather_data.csv'                             # 3. If the file is in the same folder as this notebook
]

df = None
for path in possible_paths:
    if os.path.exists(path):
        df = pd.read_csv(path)
        print(f"✅ Success! Data loaded from: {path}")
        break

if df is None:
    print(f"❌ ERROR: File 'raw_weather_data.csv' not found.")
    print(f"Current Working Directory: {os.getcwd()}")
    print("Check if your 'data' folder is visible from here!")
    # Create dummy data so you don't get a NameError later
    print("Using placeholder data for now...")
    df = pd.DataFrame({
        'temperature_c': np.linspace(20, 30, 10),
        'humidity_percent': np.linspace(50, 30, 10),
        'wind_speed_m_s': np.linspace(5, 8, 10),
        'timestamp_utc': range(1600000000, 1600000010)
    })

# Now the rest of your code (like df['datetime']) will work!
df['datetime'] = pd.to_datetime(df['timestamp_utc'], unit='s')
df.set_index('datetime', inplace=True)
df.head()
# Out:
# ❌ ERROR: File 'raw_weather_data.csv' not found.
# Current Working Directory: C:\Users\d7sakar
# Check if your 'data' folder is visible from here!
# Using placeholder data for now...
#                      temperature_c  humidity_percent  wind_speed_m_s  \
# datetime
# 2020-09-13 12:26:40      20.000000         50.000000        5.000000
# 2020-09-13 12:26:41      21.111111         47.777778        5.333333
# 2020-09-13 12:26:42      22.222222         45.555556        5.666667
# 2020-09-13 12:26:43      23.333333         43.333333        6.000000
# 2020-09-13 12:26:44      24.444444         41.111111        6.333333
#
#                      timestamp_utc
# datetime
# 2020-09-13 12:26:40     1600000000
# 2020-09-13 12:26:41     1600000001
# 2020-09-13 12:26:42     1600000002
# 2020-09-13 12:26:43     1600000003
# 2020-09-13 12:26:44     1600000004
